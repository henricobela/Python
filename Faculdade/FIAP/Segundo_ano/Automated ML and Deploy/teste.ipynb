# %%
amostras = 200

vp = 100
vn = 50
fp = 20
fn = 30

# %%
acuracia = (vp + vn) / amostras
precisao = vp / (vp + fp)
recall = vp / (vp + fn)
f_one_score = 2 * ((precisao * recall) / (precisao + recall))

# %%
acuracia
# Out:
# 0.75

# %%
precisao
# Out:
# 0.8333333333333334

# %%
recall
# Out:
# 0.7692307692307693

# %%
f_one_score
# Out:
# 0.8
