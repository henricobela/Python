# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("http://tinyurl.com/42rvaw4p")
data
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
data["smoker"] = data["smoker"].apply(lambda x: 1 if x == "yes" else 0)
data
# Out:
#       age     sex     bmi  children  smoker     region      charges
# 0      19  female  27.900         0       1  southwest  16884.92400
# 1      18    male  33.770         1       0  southeast   1725.55230
# 2      28    male  33.000         3       0  southeast   4449.46200
# 3      33    male  22.705         0       0  northwest  21984.47061
# 4      32    male  28.880         0       0  northwest   3866.85520
# ...   ...     ...     ...       ...     ...        ...          ...
# 1333   50    male  30.970         3       0  northwest  10600.54830
# 1334   18  female  31.920         0       0  northeast   2205.98080
# 1335   18  female  36.850         0       0  southeast   1629.83350
# 1336   21  female  25.800         0       0  southwest   2007.94500
# 1337   61  female  29.070         0       1  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
data["sex"] = data["sex"].apply(lambda x: 1 if x == "female" else 0)
data
# Out:
#       age  sex     bmi  children  smoker     region      charges
# 0      19    1  27.900         0       1  southwest  16884.92400
# 1      18    0  33.770         1       0  southeast   1725.55230
# 2      28    0  33.000         3       0  southeast   4449.46200
# 3      33    0  22.705         0       0  northwest  21984.47061
# 4      32    0  28.880         0       0  northwest   3866.85520
# ...   ...  ...     ...       ...     ...        ...          ...
# 1333   50    0  30.970         3       0  northwest  10600.54830
# 1334   18    1  31.920         0       0  northeast   2205.98080
# 1335   18    1  36.850         0       0  southeast   1629.83350
# 1336   21    1  25.800         0       0  southwest   2007.94500
# 1337   61    1  29.070         0       1  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
del data["region"]

# %%
data
# Out:
#       age  sex     bmi  children  smoker      charges
# 0      19    1  27.900         0       1  16884.92400
# 1      18    0  33.770         1       0   1725.55230
# 2      28    0  33.000         3       0   4449.46200
# 3      33    0  22.705         0       0  21984.47061
# 4      32    0  28.880         0       0   3866.85520
# ...   ...  ...     ...       ...     ...          ...
# 1333   50    0  30.970         3       0  10600.54830
# 1334   18    1  31.920         0       0   2205.98080
# 1335   18    1  36.850         0       0   1629.83350
# 1336   21    1  25.800         0       0   2007.94500
# 1337   61    1  29.070         0       1  29141.36030
#
# [1338 rows x 6 columns]

# %%
from sklearn.model_selection import train_test_split

label = data["charges"]
del data["charges"]
x_train, x_test, y_train, y_test = train_test_split(data, label, test_size = 0.30)

# %%
from sklearn.preprocessing import StandardScaler

ss = StandardScaler()

ss.fit(x_train)

x_train = ss.transform(x_train)
x_test = ss.transform(x_test)

# %%
n_estimators = [int(x) for x in np.linspace(100, 2000, num = 20)]
max_features = ["sqrt", "auto"]
max_depth = [int(x) for x in np.linspace(5, 30, num = 15)]
min_samples_split = [2, 5, 10, 20]
min_samples_leaf = [1, 2, 4, 5, 10]

params = {
    "n_estimators": n_estimators,
    "max_features": max_features,
    "max_depth": max_depth,
    "min_samples_split": min_samples_split,
    "min_samples_leaf": min_samples_leaf
}

# %%
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf = RandomForestRegressor(random_state = 42)

grid_rf = GridSearchCV(estimator = rf, 
                        param_grid = params,
                        cv = 3, 
                        verbose = 2, 
                        n_jobs = -1)

# %%
#grid stoped
grid_rf.fit(x_train, y_train)
# Out:
# Fitting 3 folds for each of 12000 candidates, totalling 36000 fits
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=   0.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=   0.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=   0.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   1.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   1.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   1.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   1.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   1.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   1.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=   1.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=   1.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=   1.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=700; total time=   1.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=700; total time=   2.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=700; total time=   1.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time=   2.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time=   2.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time=   2.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=900; total time=   2.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=900; total time=   2.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=900; total time=   2.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=   2.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=   2.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1100; total time=   2.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=   3.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1100; total time=   2.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1100; total time=   3.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1200; total time=   3.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1200; total time=   3.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1200; total time=   3.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1300; total time=   3.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1300; total time=   3.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1300; total time=   4.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1400; total time=   4.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1400; total time=   4.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1400; total time=   3.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1500; total time=   4.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1500; total time=   4.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1500; total time=   4.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1600; total time=   4.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1600; total time=   4.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1600; total time=   4.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1700; total time=   4.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1700; total time=   5.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1700; total time=   5.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1800; total time=   5.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1800; total time=   5.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1800; total time=   5.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   0.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   0.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1900; total time=   5.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   0.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=   0.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=   0.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1900; total time=   6.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1900; total time=   6.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=   1.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=2000; total time=   6.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=   1.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=   1.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=   1.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   1.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   1.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   1.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=2000; total time=   6.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=2000; total time=   6.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=600; total time=   1.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=600; total time=   2.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=600; total time=   2.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=700; total time=   2.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=700; total time=   2.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=700; total time=   2.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=800; total time=   2.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=800; total time=   3.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=800; total time=   3.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=900; total time=   3.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=900; total time=   4.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=900; total time=   4.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1000; total time=   4.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1000; total time=   5.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1000; total time=   4.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1100; total time=   4.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1100; total time=   4.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1100; total time=   3.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1200; total time=   4.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1200; total time=   4.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1200; total time=   4.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1300; total time=   4.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1300; total time=   4.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1400; total time=   4.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1300; total time=   4.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1400; total time=   4.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1400; total time=   4.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1500; total time=   5.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1500; total time=   4.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1500; total time=   4.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1600; total time=   4.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1600; total time=   5.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1600; total time=   5.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1700; total time=   5.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1700; total time=   5.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1700; total time=   6.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1800; total time=   5.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1800; total time=   6.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1800; total time=   5.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   0.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   0.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   0.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1900; total time=   6.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1900; total time=   6.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=   1.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1900; total time=   6.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=   1.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=   1.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=   1.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=   1.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=   1.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   1.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=2000; total time=   6.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=2000; total time=   7.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   1.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=2000; total time=   6.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   2.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=600; total time=   1.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=600; total time=   2.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=600; total time=   2.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=700; total time=   2.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=700; total time=   2.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=700; total time=   2.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time=   2.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time=   3.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time=   3.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=900; total time=   3.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=900; total time=   2.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=900; total time=   3.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=1000; total time=   3.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=1000; total time=   3.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=1000; total time=   3.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=1100; total time=   3.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=1100; total time=   3.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=1100; total time=   3.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=1200; total time=   4.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=1200; total time=   4.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=1200; total time=   4.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=1300; total time=   4.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=1300; total time=   5.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=1400; total time=   5.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=1300; total time=   5.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=1400; total time=   5.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=1400; total time=   5.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=1500; total time=   5.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=1500; total time=   6.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=1500; total time=   5.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=1600; total time=   5.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=1600; total time=   5.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=1600; total time=   6.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=1700; total time=   6.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=1700; total time=   7.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=1700; total time=   6.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=1800; total time=   7.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=1800; total time=   7.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=100; total time=   0.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=100; total time=   0.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=1800; total time=   7.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=1900; total time=   7.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=100; total time=   0.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=1900; total time=   6.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=200; total time=   0.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=200; total time=   0.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=200; total time=   0.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=1900; total time=   7.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=300; total time=   1.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=300; total time=   1.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=300; total time=   1.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=400; total time=   1.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=400; total time=   1.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=2000; total time=   7.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=400; total time=   1.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=2000; total time=   7.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=500; total time=   1.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=500; total time=   1.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=500; total time=   1.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=600; total time=   2.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=600; total time=   2.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=600; total time=   2.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=700; total time=   2.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=2000; total time=   7.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=700; total time=   2.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=700; total time=   2.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=800; total time=   3.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=800; total time=   2.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=800; total time=   3.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=900; total time=   3.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=900; total time=   3.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=900; total time=   3.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=1000; total time=   3.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=1000; total time=   3.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=1000; total time=   3.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=1100; total time=   3.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=1100; total time=   4.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=1100; total time=   3.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=1200; total time=   4.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=1200; total time=   4.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=1200; total time=   4.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=1300; total time=   4.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=1300; total time=   4.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=1300; total time=   4.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=1400; total time=   4.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=1400; total time=   5.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=1400; total time=   4.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=1500; total time=   5.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=1500; total time=   5.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=1500; total time=   5.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=1600; total time=   5.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=1600; total time=   5.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=1600; total time=   5.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=1700; total time=   5.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=1700; total time=   6.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=1700; total time=   5.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=1800; total time=   6.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=1800; total time=   6.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=1900; total time=   6.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=1800; total time=   6.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=1900; total time=   6.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=1900; total time=   6.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   1.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=   1.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=   1.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=   1.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=   1.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=   1.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=   1.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   1.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=2000; total time=   7.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   2.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=2000; total time=   7.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   2.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=   2.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=2000; total time=   7.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=   2.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=   2.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=700; total time=   2.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=700; total time=   3.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=800; total time=   3.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=700; total time=   3.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=800; total time=   2.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=800; total time=   3.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=900; total time=   3.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=900; total time=   3.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=900; total time=   3.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1000; total time=   3.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1000; total time=   4.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1000; total time=   4.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1100; total time=   4.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1100; total time=   4.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1100; total time=   4.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1200; total time=   4.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1200; total time=   4.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1200; total time=   4.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1300; total time=   4.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1300; total time=   5.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1300; total time=   5.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1400; total time=   5.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1400; total time=   5.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1400; total time=   5.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1500; total time=   5.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1500; total time=   5.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1500; total time=   6.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1600; total time=   6.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1600; total time=   6.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1600; total time=   6.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1700; total time=   6.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1700; total time=   6.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1700; total time=   6.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1800; total time=   6.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1800; total time=   7.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1800; total time=   7.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1900; total time=   7.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1900; total time=   7.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1900; total time=   7.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=   1.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=   1.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=2000; total time=   7.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=   1.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=   1.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=   1.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=2000; total time=   6.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=   1.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   1.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   1.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   1.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time=   2.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time=   2.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time=   2.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=700; total time=   2.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=2000; total time=   7.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=700; total time=   2.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=700; total time=   2.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=800; total time=   2.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=800; total time=   2.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=800; total time=   3.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=900; total time=   3.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=900; total time=   3.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=900; total time=   3.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1000; total time=   3.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1000; total time=   3.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1000; total time=   3.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1100; total time=   3.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1100; total time=   3.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1100; total time=   4.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1200; total time=   4.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1200; total time=   4.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1200; total time=   4.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1300; total time=   4.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1300; total time=   4.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1300; total time=   4.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1400; total time=   5.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1400; total time=   4.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1400; total time=   4.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1500; total time=   5.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1500; total time=   5.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1500; total time=   5.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1600; total time=   5.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1600; total time=   5.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1700; total time=   5.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1600; total time=   5.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1700; total time=   6.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1700; total time=   5.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1800; total time=   5.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1800; total time=   6.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1800; total time=   5.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   0.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   0.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1900; total time=   7.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   0.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=   1.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1900; total time=   6.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=   1.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1900; total time=   6.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=   1.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time=   1.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time=   1.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time=   1.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   1.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   1.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=2000; total time=   6.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=2000; total time=   7.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   1.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=2000; total time=   7.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=600; total time=   2.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=600; total time=   2.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=600; total time=   2.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=700; total time=   2.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=700; total time=   2.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=700; total time=   2.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time=   3.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time=   2.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time=   3.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=900; total time=   3.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=900; total time=   3.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=900; total time=   2.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1000; total time=   3.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1000; total time=   3.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1000; total time=   3.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1100; total time=   3.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1100; total time=   3.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1100; total time=   4.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1200; total time=   3.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1200; total time=   4.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1200; total time=   4.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1300; total time=   5.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1300; total time=   4.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1300; total time=   4.7s
# ...
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=20, n_estimators=1500; total time=   5.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=20, n_estimators=1400; total time=   6.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=20, n_estimators=1500; total time=   5.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=20, n_estimators=1500; total time=   5.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=20, n_estimators=1600; total time=   6.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=20, n_estimators=1600; total time=   6.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=20, n_estimators=1600; total time=   6.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=20, n_estimators=1700; total time=   6.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=20, n_estimators=1700; total time=   6.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=20, n_estimators=1700; total time=   7.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=20, n_estimators=1800; total time=   6.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=20, n_estimators=1800; total time=   7.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=20, n_estimators=1800; total time=   7.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=20, n_estimators=1900; total time=   7.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   0.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   0.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   0.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=20, n_estimators=1900; total time=   6.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=   1.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=20, n_estimators=1900; total time=   8.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=   1.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=   1.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=   1.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=   1.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=   1.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   2.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   2.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=20, n_estimators=2000; total time=   8.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   1.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=20, n_estimators=2000; total time=   8.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=20, n_estimators=2000; total time=   8.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=600; total time=   2.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=600; total time=   2.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=600; total time=   2.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=700; total time=   2.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=700; total time=   2.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=700; total time=   2.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=800; total time=   2.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=800; total time=   2.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=800; total time=   3.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=900; total time=   3.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=900; total time=   3.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=900; total time=   3.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=1000; total time=   4.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=1000; total time=   4.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=1000; total time=   3.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=1100; total time=   3.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=1100; total time=   3.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=1100; total time=   5.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=1200; total time=   4.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=1200; total time=   4.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=1200; total time=   5.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=1300; total time=   5.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=1300; total time=   5.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=1300; total time=   5.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=1400; total time=   5.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=1400; total time=   5.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=1400; total time=   5.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=1500; total time=   5.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=1500; total time=   4.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=1500; total time=   5.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=1600; total time=   6.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=1600; total time=   5.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=1600; total time=   5.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=1700; total time=   6.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=1700; total time=   6.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=1700; total time=   6.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=1800; total time=   6.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=1800; total time=   6.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   0.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   0.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   0.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=1900; total time=   7.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=1900; total time=   7.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   0.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=1800; total time=   7.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   0.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   0.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=   1.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=   1.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=1900; total time=   7.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=   1.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=400; total time=   1.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=400; total time=   1.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=400; total time=   1.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=2000; total time=   8.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   2.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   2.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   2.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=2000; total time=   8.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=600; total time=   2.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=600; total time=   2.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=600; total time=   2.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=2000; total time=   8.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=700; total time=   2.7s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/valkiryan/Github/Python/Faculdade/Machine Learning & Redes Neurais/grid_search_e_random_search.ipynb Cell 13 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/valkiryan/Github/Python/Faculdade/Machine%20Learning%20%26%20Redes%20Neurais/grid_search_e_random_search.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> grid_rf.fit(x_train, y_train)
#
# File ~/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_search.py:891, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     885     results = self._format_results(
#     886         all_candidate_params, n_splits, all_out, all_more_results
#     887     )
#     889     return results
# --> 891 self._run_search(evaluate_candidates)
#     893 # multimetric is determined here because in the case of a callable
#     894 # self.scoring the return type is only known after calling
#     895 first_test_score = all_out[0]["test_scores"]
#
# File ~/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_search.py:1392, in GridSearchCV._run_search(self, evaluate_candidates)
#    1390 def _run_search(self, evaluate_candidates):
#    1391     """Search all candidates in param_grid"""
# -> 1392     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File ~/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_search.py:838, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     830 if self.verbose > 0:
#     831     print(
#     832         "Fitting {0} folds for each of {1} candidates,"
#     833         " totalling {2} fits".format(
#     834             n_splits, n_candidates, n_candidates * n_splits
#     835         )
#     836     )
# --> 838 out = parallel(
#     839     delayed(_fit_and_score)(
#     840         clone(base_estimator),
#     841         X,
#     842         y,
#     843         train=train,
#     844         test=test,
#     845         parameters=parameters,
#     846         split_progress=(split_idx, n_splits),
#     847         candidate_progress=(cand_idx, n_candidates),
#     848         **fit_and_score_kwargs,
#     849     )
#     850     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     851         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     852     )
#     853 )
#     855 if len(out) < 1:
#     856     raise ValueError(
#     857         "No fits were performed. "
#     858         "Was the CV iterator empty? "
#     859         "Were there no candidates?"
#     860     )
#
# File ~/anaconda3/lib/python3.9/site-packages/joblib/parallel.py:1056, in Parallel.__call__(self, iterable)
#    1053     self._iterating = False
#    1055 with self._backend.retrieval_context():
# -> 1056     self.retrieve()
#    1057 # Make sure that we get a last message telling us we are done
#    1058 elapsed_time = time.time() - self._start_time
#
# File ~/anaconda3/lib/python3.9/site-packages/joblib/parallel.py:935, in Parallel.retrieve(self)
#     933 try:
#     934     if getattr(self._backend, 'supports_timeout', False):
# --> 935         self._output.extend(job.get(timeout=self.timeout))
#     936     else:
#     937         self._output.extend(job.get())
#
# File ~/anaconda3/lib/python3.9/site-packages/joblib/_parallel_backends.py:542, in LokyBackend.wrap_future_result(future, timeout)
#     539 """Wrapper for Future.result to implement the same behaviour as
#     540 AsyncResults.get from multiprocessing."""
#     541 try:
# --> 542     return future.result(timeout=timeout)
#     543 except CfTimeoutError as e:
#     544     raise TimeoutError from e
#
# File ~/anaconda3/lib/python3.9/concurrent/futures/_base.py:441, in Future.result(self, timeout)
#     438 elif self._state == FINISHED:
#     439     return self.__get_result()
# --> 441 self._condition.wait(timeout)
#     443 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     444     raise CancelledError()
#
# File ~/anaconda3/lib/python3.9/threading.py:312, in Condition.wait(self, timeout)
#     310 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     311     if timeout is None:
# --> 312         waiter.acquire()
#     313         gotit = True
#     314     else:
#
# KeyboardInterrupt:

# %%
random_rf = RandomizedSearchCV(estimator = rf, 
                                param_distributions = params,
                                cv = 3,
                                verbose = 2,
                                n_jobs = -1,
                                random_state = 42,
                                n_iter = 100)

# %%
random_rf.fit(x_train, y_train)
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=100; total time=   0.3s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=100; total time=   0.3s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=100; total time=   0.5s
# [CV] END max_depth=21, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=1100; total time=   2.7s
# [CV] END max_depth=21, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=1100; total time=   2.8s
# [CV] END max_depth=21, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=1100; total time=   3.3s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=1100; total time=   3.6s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, n_estimators=1200; total time=   3.4s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=10, min_samples_split=10, n_estimators=500; total time=   1.4s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=1100; total time=   3.8s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=1100; total time=   4.0s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, n_estimators=1200; total time=   3.8s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=10, min_samples_split=10, n_estimators=500; total time=   1.6s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=10, min_samples_split=10, n_estimators=500; total time=   1.7s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   1.5s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   1.7s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   1.5s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, n_estimators=1200; total time=   3.3s
# [CV] END max_depth=17, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=600; total time=   2.2s
# [CV] END max_depth=17, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=600; total time=   1.9s
# [CV] END max_depth=5, max_features=auto, min_samples_leaf=1, min_samples_split=20, n_estimators=700; total time=   2.2s
# [CV] END max_depth=17, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=600; total time=   2.2s
# [CV] END max_depth=5, max_features=auto, min_samples_leaf=1, min_samples_split=20, n_estimators=700; total time=   2.2s
# [CV] END max_depth=17, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1500; total time=   4.6s
# [CV] END max_depth=17, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1500; total time=   4.7s
# [CV] END max_depth=17, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1500; total time=   4.7s
# [CV] END max_depth=5, max_features=auto, min_samples_leaf=1, min_samples_split=20, n_estimators=700; total time=   2.1s
# [CV] END max_depth=13, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=700; total time=   2.6s
# [CV] END max_depth=13, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=700; total time=   2.8s
# [CV] END max_depth=13, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=700; total time=   2.9s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=   1.5s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=   1.3s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=   1.4s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=10, min_samples_split=10, n_estimators=1900; total time=   6.5s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=10, min_samples_split=10, n_estimators=1900; total time=   6.5s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=10, min_samples_split=10, n_estimators=1900; total time=   6.8s
# [CV] END max_depth=22, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=300; total time=   0.9s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=1700; total time=   7.0s
# [CV] END max_depth=28, max_features=auto, min_samples_leaf=5, min_samples_split=20, n_estimators=1200; total time=   4.5s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=1700; total time=   7.6s
# [CV] END max_depth=22, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=300; total time=   1.0s
# [CV] END max_depth=22, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=300; total time=   1.0s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=1700; total time=   7.5s
# [CV] END max_depth=28, max_features=auto, min_samples_leaf=5, min_samples_split=20, n_estimators=1200; total time=   4.1s
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=   2.2s
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=   2.2s
# [CV] END max_depth=28, max_features=auto, min_samples_leaf=5, min_samples_split=20, n_estimators=1200; total time=   4.4s
# [CV] END max_depth=28, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=400; total time=   1.7s
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=   2.3s
# [CV] END max_depth=28, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=400; total time=   1.3s
# [CV] END max_depth=28, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=400; total time=   1.5s
# [CV] END max_depth=5, max_features=auto, min_samples_leaf=10, min_samples_split=10, n_estimators=1000; total time=   3.2s
# [CV] END max_depth=5, max_features=auto, min_samples_leaf=10, min_samples_split=10, n_estimators=1000; total time=   3.4s
# [CV] END max_depth=5, max_features=auto, min_samples_leaf=10, min_samples_split=10, n_estimators=1000; total time=   3.6s
# [CV] END max_depth=19, max_features=auto, min_samples_leaf=2, min_samples_split=20, n_estimators=1000; total time=   3.4s
# [CV] END max_depth=19, max_features=auto, min_samples_leaf=2, min_samples_split=20, n_estimators=1000; total time=   3.6s
# [CV] END max_depth=19, max_features=auto, min_samples_leaf=2, min_samples_split=20, n_estimators=1000; total time=   3.8s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1400; total time=   5.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1400; total time=   5.0s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=1200; total time=   5.0s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1400; total time=   5.3s
# [CV] END max_depth=19, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.4s
# [CV] END max_depth=19, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.4s
# [CV] END max_depth=19, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.4s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=1200; total time=   5.7s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=1200; total time=   3.9s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=1200; total time=   4.6s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, n_estimators=500; total time=   1.6s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, n_estimators=500; total time=   1.6s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, n_estimators=500; total time=   1.6s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=1200; total time=   4.7s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=1200; total time=   4.0s
# [CV] END max_depth=12, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=600; total time=   2.2s
# [CV] END max_depth=12, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=600; total time=   2.1s
# [CV] END max_depth=12, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=600; total time=   2.3s
# [CV] END max_depth=13, max_features=auto, min_samples_leaf=2, min_samples_split=20, n_estimators=1600; total time=   7.0s
# [CV] END max_depth=13, max_features=auto, min_samples_leaf=2, min_samples_split=20, n_estimators=1600; total time=   7.5s
# [CV] END max_depth=13, max_features=auto, min_samples_leaf=2, min_samples_split=20, n_estimators=1600; total time=   7.9s
# [CV] END max_depth=17, max_features=auto, min_samples_leaf=10, min_samples_split=20, n_estimators=1700; total time=   7.2s
# [CV] END max_depth=17, max_features=auto, min_samples_leaf=10, min_samples_split=20, n_estimators=1700; total time=   6.7s
# [CV] END max_depth=17, max_features=auto, min_samples_leaf=10, min_samples_split=20, n_estimators=1700; total time=   7.3s
# [CV] END max_depth=22, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=700; total time=   2.6s
# [CV] END max_depth=28, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=1700; total time=   7.7s
# [CV] END max_depth=28, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=1700; total time=   7.7s
# [CV] END max_depth=22, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=700; total time=   2.9s
# [CV] END max_depth=22, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=700; total time=   2.9s
# [CV] END max_depth=28, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=1700; total time=   6.6s
# [CV] END max_depth=21, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=1000; total time=   4.2s
# [CV] END max_depth=24, max_features=auto, min_samples_leaf=1, min_samples_split=20, n_estimators=1500; total time=   6.1s
# [CV] END max_depth=24, max_features=auto, min_samples_leaf=1, min_samples_split=20, n_estimators=1500; total time=   5.7s
# [CV] END max_depth=24, max_features=auto, min_samples_leaf=1, min_samples_split=20, n_estimators=1500; total time=   5.8s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=20, n_estimators=1900; total time=   7.0s
# [CV] END max_depth=21, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=1000; total time=   4.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=20, n_estimators=1900; total time=   7.0s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=20, n_estimators=1900; total time=   7.3s
# [CV] END max_depth=8, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time=   3.4s
# [CV] END max_depth=8, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time=   3.6s
# [CV] END max_depth=21, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=1000; total time=   4.1s
# [CV] END max_depth=8, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time=   3.6s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=800; total time=   2.7s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=800; total time=   2.8s
# [CV] END max_depth=24, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=800; total time=   2.7s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=800; total time=   3.4s
# [CV] END max_depth=24, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=800; total time=   3.0s
# [CV] END max_depth=24, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=800; total time=   3.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=1000; total time=   3.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=1000; total time=   3.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=1000; total time=   4.4s
# [CV] END max_depth=26, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, n_estimators=1900; total time=   7.2s
# [CV] END max_depth=26, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, n_estimators=1900; total time=   7.7s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=600; total time=   2.9s
# [CV] END max_depth=26, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, n_estimators=1900; total time=   7.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=1500; total time=   5.9s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=1500; total time=   6.3s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=600; total time=   2.8s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=600; total time=   3.0s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=1500; total time=   7.1s
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=2000; total time=   8.4s
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=2000; total time=   7.8s
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=2000; total time=   8.1s
# [CV] END max_depth=13, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=1900; total time=   9.3s
# [CV] END max_depth=13, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=1900; total time=   9.4s
# [CV] END max_depth=13, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=1900; total time=   9.7s
# [CV] END max_depth=21, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=1500; total time=   7.8s
# [CV] END max_depth=21, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=1500; total time=   7.5s
# [CV] END max_depth=6, max_features=auto, min_samples_leaf=1, min_samples_split=20, n_estimators=800; total time=   4.0s
# [CV] END max_depth=6, max_features=auto, min_samples_leaf=1, min_samples_split=20, n_estimators=800; total time=   3.9s
# [CV] END max_depth=6, max_features=auto, min_samples_leaf=1, min_samples_split=20, n_estimators=800; total time=   4.1s
# [CV] END max_depth=6, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=900; total time=   5.1s
# [CV] END max_depth=6, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=900; total time=   5.1s
# [CV] END max_depth=6, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=900; total time=   5.3s
# [CV] END max_depth=21, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=1500; total time=   7.9s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=1500; total time=   8.1s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=1500; total time=   7.1s
# [CV] END max_depth=12, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=1100; total time=   5.5s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=1500; total time=   8.2s
# [CV] END max_depth=12, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=1700; total time=   8.2s
# [CV] END max_depth=12, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=1700; total time=   7.6s
# [CV] END max_depth=28, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   0.5s
# [CV] END max_depth=12, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=1700; total time=   7.6s
# [CV] END max_depth=12, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=1100; total time=   5.9s
# [CV] END max_depth=28, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   0.4s
# [CV] END max_depth=28, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   0.6s
# [CV] END max_depth=12, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=1100; total time=   5.6s
# [CV] END max_depth=28, max_features=sqrt, min_samples_leaf=4, min_samples_split=20, n_estimators=800; total time=   3.2s
# [CV] END max_depth=24, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1900; total time=   8.8s
# [CV] END max_depth=24, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1900; total time=   8.0s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=1400; total time=   6.5s[CV] END max_depth=15, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=1400; total time=   6.3s
#
# [CV] END max_depth=28, max_features=sqrt, min_samples_leaf=4, min_samples_split=20, n_estimators=800; total time=   3.4s
# [CV] END max_depth=28, max_features=sqrt, min_samples_leaf=4, min_samples_split=20, n_estimators=800; total time=   3.2s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=1400; total time=   6.6s
# [CV] END max_depth=24, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1900; total time=   8.9s
# [CV] END max_depth=22, max_features=auto, min_samples_leaf=10, min_samples_split=20, n_estimators=1300; total time=   5.2s
# [CV] END max_depth=22, max_features=auto, min_samples_leaf=10, min_samples_split=20, n_estimators=1300; total time=   5.4s
# [CV] END max_depth=22, max_features=auto, min_samples_leaf=10, min_samples_split=20, n_estimators=1300; total time=   5.6s
# [CV] END max_depth=28, max_features=sqrt, min_samples_leaf=2, min_samples_split=20, n_estimators=1600; total time=   6.1s
# [CV] END max_depth=28, max_features=sqrt, min_samples_leaf=2, min_samples_split=20, n_estimators=1600; total time=   6.5s
# [CV] END max_depth=28, max_features=sqrt, min_samples_leaf=2, min_samples_split=20, n_estimators=1600; total time=   6.6s
# [CV] END max_depth=26, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=1400; total time=   6.6s
# [CV] END max_depth=26, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=1400; total time=   6.3s
# [CV] END max_depth=26, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=1400; total time=   5.6s
# [CV] END max_depth=26, max_features=auto, min_samples_leaf=4, min_samples_split=20, n_estimators=1400; total time=   5.7s
# [CV] END max_depth=26, max_features=auto, min_samples_leaf=4, min_samples_split=20, n_estimators=1400; total time=   6.0s
# [CV] END max_depth=22, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=1400; total time=   7.2s
# [CV] END max_depth=22, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=1400; total time=   6.1s
# [CV] END max_depth=22, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=1400; total time=   7.0s
# [CV] END max_depth=26, max_features=auto, min_samples_leaf=4, min_samples_split=20, n_estimators=1400; total time=   6.1s
# [CV] END max_depth=28, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=1700; total time=   7.7s
# [CV] END max_depth=21, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, n_estimators=1400; total time=   5.2s
# [CV] END max_depth=21, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, n_estimators=1400; total time=   5.4s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=1300; total time=   5.5s
# [CV] END max_depth=21, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, n_estimators=1400; total time=   6.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=1300; total time=   6.2s
# [CV] END max_depth=19, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=200; total time=   1.1s
# [CV] END max_depth=19, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=200; total time=   1.1s
# [CV] END max_depth=28, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=1700; total time=   8.2s
# [CV] END max_depth=19, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=200; total time=   1.0s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=1300; total time=   5.3s
# [CV] END max_depth=28, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=1700; total time=   8.5s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=700; total time=   3.7s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=700; total time=   3.8s
# [CV] END max_depth=24, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=1600; total time=   7.0s
# [CV] END max_depth=24, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=1600; total time=   7.1s
# [CV] END max_depth=24, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=1600; total time=   8.2s
# [CV] END max_depth=17, max_features=auto, min_samples_leaf=4, min_samples_split=20, n_estimators=1600; total time=   7.4s
# [CV] END max_depth=17, max_features=auto, min_samples_leaf=4, min_samples_split=20, n_estimators=1600; total time=   8.4s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=700; total time=   3.8s
# [CV] END max_depth=17, max_features=auto, min_samples_leaf=4, min_samples_split=20, n_estimators=1600; total time=   9.0s
# [CV] END max_depth=28, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=900; total time=   3.4s
# [CV] END max_depth=26, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=1100; total time=   4.7s
# [CV] END max_depth=26, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=1100; total time=   5.0s
# [CV] END max_depth=28, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=900; total time=   4.0s
# [CV] END max_depth=26, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=1100; total time=   4.6s
# [CV] END max_depth=19, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=2000; total time=   9.6s
# [CV] END max_depth=28, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=900; total time=   3.1s
# [CV] END max_depth=22, max_features=sqrt, min_samples_leaf=4, min_samples_split=20, n_estimators=700; total time=   2.6s
# [CV] END max_depth=19, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=2000; total time=   9.2s
# [CV] END max_depth=19, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=2000; total time=   9.8s
# [CV] END max_depth=22, max_features=sqrt, min_samples_leaf=4, min_samples_split=20, n_estimators=700; total time=   2.8s
# [CV] END max_depth=22, max_features=sqrt, min_samples_leaf=4, min_samples_split=20, n_estimators=700; total time=   2.9s
# [CV] END max_depth=5, max_features=auto, min_samples_leaf=10, min_samples_split=10, n_estimators=1600; total time=   7.4s
# [CV] END max_depth=5, max_features=auto, min_samples_leaf=10, min_samples_split=10, n_estimators=1600; total time=   7.3s
# [CV] END max_depth=5, max_features=auto, min_samples_leaf=10, min_samples_split=10, n_estimators=1600; total time=   7.6s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=1300; total time=   6.1s
# [CV] END max_depth=26, max_features=auto, min_samples_leaf=2, min_samples_split=20, n_estimators=800; total time=   4.0s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=1300; total time=   6.2s
# [CV] END max_depth=26, max_features=auto, min_samples_leaf=2, min_samples_split=20, n_estimators=800; total time=   4.4s
# [CV] END max_depth=6, max_features=auto, min_samples_leaf=10, min_samples_split=20, n_estimators=600; total time=   3.0s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=1300; total time=   6.6s
# [CV] END max_depth=6, max_features=auto, min_samples_leaf=10, min_samples_split=20, n_estimators=600; total time=   3.4s
# [CV] END max_depth=12, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=400; total time=   2.0s
# [CV] END max_depth=26, max_features=auto, min_samples_leaf=2, min_samples_split=20, n_estimators=800; total time=   4.4s
# [CV] END max_depth=12, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=400; total time=   2.1s
# [CV] END max_depth=12, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=400; total time=   2.2s
# [CV] END max_depth=6, max_features=auto, min_samples_leaf=10, min_samples_split=20, n_estimators=600; total time=   3.4s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=4, min_samples_split=20, n_estimators=200; total time=   0.9s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=4, min_samples_split=20, n_estimators=200; total time=   0.9s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=4, min_samples_split=20, n_estimators=200; total time=   0.9s
# [CV] END max_depth=21, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=1600; total time=   8.3s
# [CV] END max_depth=21, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=1600; total time=   8.7s
# [CV] END max_depth=21, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=1600; total time=   8.4s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=1400; total time=   8.3s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=1400; total time=   9.4s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=1400; total time=   9.3s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=1400; total time=   8.7s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=1400; total time=   8.8s
# [CV] END max_depth=12, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=400; total time=   2.1s
# [CV] END max_depth=28, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=   3.9s
# [CV] END max_depth=12, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=400; total time=   2.3s
# [CV] END max_depth=28, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=   4.3s
# [CV] END max_depth=12, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=400; total time=   2.2s
# [CV] END max_depth=28, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=   4.6s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=1400; total time=   8.8s
# [CV] END max_depth=21, max_features=auto, min_samples_leaf=10, min_samples_split=20, n_estimators=1000; total time=   5.2s
# [CV] END max_depth=21, max_features=auto, min_samples_leaf=10, min_samples_split=20, n_estimators=1000; total time=   5.7s
# [CV] END max_depth=21, max_features=auto, min_samples_leaf=10, min_samples_split=20, n_estimators=1000; total time=   6.0s
# [CV] END max_depth=26, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1300; total time=   7.5s
# [CV] END max_depth=26, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1300; total time=   7.8s
# [CV] END max_depth=26, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1300; total time=   8.0s
# [CV] END max_depth=19, max_features=auto, min_samples_leaf=1, min_samples_split=20, n_estimators=1400; total time=   7.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   1.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   0.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   1.1s
# [CV] END max_depth=19, max_features=auto, min_samples_leaf=1, min_samples_split=20, n_estimators=1400; total time=   7.4s
# [CV] END max_depth=19, max_features=auto, min_samples_leaf=1, min_samples_split=20, n_estimators=1400; total time=   7.6s
# [CV] END max_depth=17, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=1600; total time=   8.3s
# [CV] END max_depth=17, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=1600; total time=   8.2s
# [CV] END max_depth=17, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=1600; total time=   7.7s
# [CV] END max_depth=13, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=1800; total time=   8.6s
# [CV] END max_depth=13, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=1800; total time=   9.1s
# [CV] END max_depth=13, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=1800; total time=   9.4s
# [CV] END max_depth=26, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=1400; total time=   8.2s
# [CV] END max_depth=26, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=1400; total time=   8.7s
# [CV] END max_depth=26, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=1400; total time=   7.7s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=1600; total time=   7.7s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=1600; total time=   7.2s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=1500; total time=   6.4s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=1600; total time=   7.0s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=1500; total time=   6.3s
# [CV] END max_depth=21, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=1000; total time=   4.9s
# [CV] END max_depth=21, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=1000; total time=   5.6s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=1500; total time=   6.8s
# [CV] END max_depth=21, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=1000; total time=   5.3s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=10, min_samples_split=20, n_estimators=1100; total time=   5.6s
# [CV] END max_depth=24, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=800; total time=   4.3s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=10, min_samples_split=20, n_estimators=1100; total time=   5.4s
# [CV] END max_depth=24, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=800; total time=   4.2s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=10, min_samples_split=20, n_estimators=1100; total time=   5.5s
# [CV] END max_depth=24, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=800; total time=   5.2s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=1700; total time=   7.4s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=1700; total time=   7.4s
# [CV] END max_depth=21, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=1000; total time=   5.1s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=1700; total time=   7.2s
# [CV] END max_depth=21, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=1000; total time=   4.8s
# [CV] END max_depth=21, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=1000; total time=   5.1s
# [CV] END max_depth=19, max_features=auto, min_samples_leaf=1, min_samples_split=20, n_estimators=400; total time=   1.8s
# [CV] END max_depth=19, max_features=auto, min_samples_leaf=1, min_samples_split=20, n_estimators=400; total time=   1.9s
# [CV] END max_depth=19, max_features=auto, min_samples_leaf=1, min_samples_split=20, n_estimators=400; total time=   2.0s
# [CV] END max_depth=19, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=2000; total time=   8.9s
# [CV] END max_depth=21, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=1300; total time=   5.6s
# [CV] END max_depth=19, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=2000; total time=   9.5s
# [CV] END max_depth=21, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=1300; total time=   6.4s
# [CV] END max_depth=21, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=1300; total time=   6.2s
# [CV] END max_depth=19, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=2000; total time=   8.8s
# [CV] END max_depth=22, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=1000; total time=   4.7s
# [CV] END max_depth=21, max_features=auto, min_samples_leaf=5, min_samples_split=20, n_estimators=1700; total time=   8.1s
# [CV] END max_depth=22, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=1000; total time=   5.2s
# [CV] END max_depth=22, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=1000; total time=   5.5s
# [CV] END max_depth=21, max_features=auto, min_samples_leaf=5, min_samples_split=20, n_estimators=1700; total time=   7.9s
# [CV] END max_depth=21, max_features=auto, min_samples_leaf=5, min_samples_split=20, n_estimators=1700; total time=   8.4s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=1900; total time=   7.2s
# [CV] END max_depth=24, max_features=auto, min_samples_leaf=1, min_samples_split=20, n_estimators=900; total time=   4.3s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=1900; total time=   7.3s
# [CV] END max_depth=24, max_features=auto, min_samples_leaf=1, min_samples_split=20, n_estimators=900; total time=   4.6s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=800; total time=   3.3s
# [CV] END max_depth=24, max_features=auto, min_samples_leaf=1, min_samples_split=20, n_estimators=900; total time=   4.3s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=800; total time=   3.3s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=800; total time=   2.7s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=1900; total time=   7.0s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/valkiryan/Github/Python/Faculdade/Machine Learning & Redes Neurais/grid_search_e_random_search.ipynb Cell 15 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/valkiryan/Github/Python/Faculdade/Machine%20Learning%20%26%20Redes%20Neurais/grid_search_e_random_search.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> random_rf.fit(x_train, y_train)
#
# File ~/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_search.py:926, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     924 refit_start_time = time.time()
#     925 if y is not None:
# --> 926     self.best_estimator_.fit(X, y, **fit_params)
#     927 else:
#     928     self.best_estimator_.fit(X, **fit_params)
#
# File ~/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:450, in BaseForest.fit(self, X, y, sample_weight)
#     439 trees = [
#     440     self._make_estimator(append=False, random_state=random_state)
#     441     for i in range(n_more_estimators)
#     442 ]
#     444 # Parallel loop: we prefer the threading backend as the Cython code
#     445 # for fitting the trees is internally releasing the Python GIL
#     446 # making threading more efficient than multiprocessing in
#     447 # that case. However, for joblib 0.12+ we respect any
#     448 # parallel_backend contexts set at a higher level,
#     449 # since correctness does not rely on using threads.
# --> 450 trees = Parallel(
#     451     n_jobs=self.n_jobs,
#     452     verbose=self.verbose,
#     453     **_joblib_parallel_args(prefer="threads"),
#     454 )(
#     455     delayed(_parallel_build_trees)(
#     456         t,
#     457         self,
#     458         X,
#     459         y,
#     460         sample_weight,
#     461         i,
#     462         len(trees),
#     463         verbose=self.verbose,
#     464         class_weight=self.class_weight,
#     465         n_samples_bootstrap=n_samples_bootstrap,
#     466     )
#     467     for i, t in enumerate(trees)
#     468 )
#     470 # Collect newly grown trees
#     471 self.estimators_.extend(trees)
#
# File ~/anaconda3/lib/python3.9/site-packages/joblib/parallel.py:1046, in Parallel.__call__(self, iterable)
#    1043 if self.dispatch_one_batch(iterator):
#    1044     self._iterating = self._original_iterator is not None
# -> 1046 while self.dispatch_one_batch(iterator):
#    1047     pass
#    1049 if pre_dispatch == "all" or n_jobs == 1:
#    1050     # The iterable was consumed all at once by the above for loop.
#    1051     # No need to wait for async callbacks to trigger to
#    1052     # consumption.
#
# File ~/anaconda3/lib/python3.9/site-packages/joblib/parallel.py:861, in Parallel.dispatch_one_batch(self, iterator)
#     859     return False
#     860 else:
# --> 861     self._dispatch(tasks)
#     862     return True
#
# File ~/anaconda3/lib/python3.9/site-packages/joblib/parallel.py:779, in Parallel._dispatch(self, batch)
#     777 with self._lock:
#     778     job_idx = len(self._jobs)
# --> 779     job = self._backend.apply_async(batch, callback=cb)
#     780     # A job can complete so quickly than its callback is
#     781     # called before we get here, causing self._jobs to
#     782     # grow. To ensure correct results ordering, .insert is
#     783     # used (rather than .append) in the following line
#     784     self._jobs.insert(job_idx, job)
#
# File ~/anaconda3/lib/python3.9/site-packages/joblib/_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File ~/anaconda3/lib/python3.9/site-packages/joblib/_parallel_backends.py:572, in ImmediateResult.__init__(self, batch)
#     569 def __init__(self, batch):
#     570     # Don't delay the application, to avoid keeping the input
#     571     # arguments in memory
# --> 572     self.results = batch()
#
# File ~/anaconda3/lib/python3.9/site-packages/joblib/parallel.py:262, in BatchedCalls.__call__(self)
#     258 def __call__(self):
#     259     # Set the default nested backend to self._backend but do not set the
#     260     # change the default number of processes to -1
#     261     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262         return [func(*args, **kwargs)
#     263                 for func, args, kwargs in self.items]
#
# File ~/anaconda3/lib/python3.9/site-packages/joblib/parallel.py:262, in <listcomp>(.0)
#     258 def __call__(self):
#     259     # Set the default nested backend to self._backend but do not set the
#     260     # change the default number of processes to -1
#     261     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262         return [func(*args, **kwargs)
#     263                 for func, args, kwargs in self.items]
#
# File ~/anaconda3/lib/python3.9/site-packages/sklearn/utils/fixes.py:216, in _FuncWrapper.__call__(self, *args, **kwargs)
#     214 def __call__(self, *args, **kwargs):
#     215     with config_context(**self.config):
# --> 216         return self.function(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:172, in _parallel_build_trees(tree, forest, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap)
#     169 else:
#     170     curr_sample_weight = sample_weight.copy()
# --> 172 indices = _generate_sample_indices(
#     173     tree.random_state, n_samples, n_samples_bootstrap
#     174 )
#     175 sample_counts = np.bincount(indices, minlength=n_samples)
#     176 curr_sample_weight *= sample_counts
#
# File ~/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:128, in _generate_sample_indices(random_state, n_samples, n_samples_bootstrap)
#     124 def _generate_sample_indices(random_state, n_samples, n_samples_bootstrap):
#     125     """
#     126     Private function used to _parallel_build_trees function."""
# --> 128     random_instance = check_random_state(random_state)
#     129     sample_indices = random_instance.randint(0, n_samples, n_samples_bootstrap)
#     131     return sample_indices
#
# File ~/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:1057, in check_random_state(seed)
#    1055     return np.random.mtrand._rand
#    1056 if isinstance(seed, numbers.Integral):
# -> 1057     return np.random.RandomState(seed)
#    1058 if isinstance(seed, np.random.RandomState):
#    1059     return seed
#
# File mtrand.pyx:184, in numpy.random.mtrand.RandomState.__init__()
#
# File _mt19937.pyx:130, in numpy.random._mt19937.MT19937.__init__()
#
# File ~/anaconda3/lib/python3.9/contextlib.py:76, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      75 def __call__(self, func):
# ---> 76     @wraps(func)
#      77     def inner(*args, **kwds):
#      78         with self._recreate_cm():
#      79             return func(*args, **kwds)
#
# KeyboardInterrupt:

# %%
random_rf.best_estimator_
# Out:
# RandomForestRegressor(max_depth=5, min_samples_leaf=10, min_samples_split=10,
#                       n_estimators=1600, random_state=42)

# %%
random_rf.best_score_
# Out:
# 0.8565250288012102

# %%
best_model = random_rf.best_estimator_
best_model.fit(x_train, y_train)
y_pred = best_model.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error as MSE
from sklearn.metrics import r2_score as r2

# %%
print(f"MSE: {MSE(y_test, y_pred)}")
# Out:
# MSE: 20384505.423422016

# %%
print(f"R2: {round(r2(y_test, y_pred), 2)}")
# Out:
# R2: 0.86
