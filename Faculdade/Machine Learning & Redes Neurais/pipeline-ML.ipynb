# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("https://raw.githubusercontent.com/MicrosoftDocs/ml-basics/master/data/daily-bike-share.csv")
data
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1    1/1/2011       1   0     1        0        6           0
# 1          2    1/2/2011       1   0     1        0        0           0
# 2          3    1/3/2011       1   0     1        0        1           1
# 3          4    1/4/2011       1   0     1        0        2           1
# 4          5    1/5/2011       1   0     1        0        3           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 726      727  12/27/2012       1   1    12        0        4           1
# 727      728  12/28/2012       1   1    12        0        5           1
# 728      729  12/29/2012       1   1    12        0        6           0
# 729      730  12/30/2012       1   1    12        0        0           0
# 730      731  12/31/2012       1   1    12        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  rentals
# ...

# %%
data.dtypes
# Out:
# instant         int64
# dteday         object
# season          int64
# yr              int64
# mnth            int64
# holiday         int64
# weekday         int64
# workingday      int64
# weathersit      int64
# temp          float64
# atemp         float64
# hum           float64
# windspeed     float64
# rentals         int64
# dtype: object

# %%
data.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# rentals       0
# dtype: int64

# %%
import random

# %%
ix = [(row, col) for row in range(data.shape[0]) for col in range(data.shape[-1]-1)]

for row, col in random.sample(ix, int(round(0.1*len(ix)))):
    data.iat[row, col] = np.nan

# %%
data.isnull().sum()
# Out:
# instant       78
# dteday        71
# season        73
# yr            74
# mnth          76
# holiday       71
# weekday       67
# workingday    77
# weathersit    62
# temp          81
# atemp         77
# hum           78
# windspeed     65
# rentals        0
# dtype: int64

# %%
data.sample(20)
# Out:
#      instant      dteday  season   yr  mnth  holiday  weekday  workingday  \
# 602    603.0   8/25/2012     NaN  1.0   8.0      0.0      6.0         NaN
# 674    675.0         NaN     4.0  1.0   NaN      0.0      1.0         1.0
# 481    482.0   4/26/2012     2.0  1.0   4.0      0.0      4.0         1.0
# 298    299.0  10/26/2011     4.0  0.0  10.0      0.0      3.0         NaN
# 389    390.0   1/25/2012     1.0  1.0   1.0      0.0      3.0         1.0
# 50      51.0   2/20/2011     1.0  0.0   2.0      0.0      NaN         0.0
# 156    157.0    6/6/2011     2.0  0.0   6.0      0.0      1.0         1.0
# 59      60.0    3/1/2011     1.0  0.0   3.0      0.0      2.0         1.0
# 573    574.0   7/27/2012     3.0  NaN   7.0      0.0      5.0         1.0
# 610    611.0    9/2/2012     3.0  1.0   9.0      0.0      0.0         0.0
# 633    634.0   9/25/2012     4.0  1.0   9.0      0.0      2.0         1.0
# 307    308.0   11/4/2011     4.0  NaN  11.0      0.0      5.0         1.0
# ...

# %%
data = data[["season", "mnth", "holiday", "weekday", "workingday", 
            "weathersit", "temp", "atemp", "hum", "windspeed", "rentals"]]

# %%
data
# Out:
#      season  mnth  holiday  weekday  workingday  weathersit      temp  \
# 0       1.0   1.0      0.0      6.0         0.0         2.0  0.344167
# 1       1.0   1.0      0.0      0.0         0.0         2.0  0.363478
# 2       1.0   1.0      0.0      1.0         1.0         1.0  0.196364
# 3       1.0   1.0      0.0      2.0         1.0         1.0  0.200000
# 4       1.0   1.0      0.0      3.0         1.0         1.0  0.226957
# ..      ...   ...      ...      ...         ...         ...       ...
# 726     1.0  12.0      0.0      4.0         1.0         2.0  0.254167
# 727     1.0  12.0      NaN      5.0         1.0         2.0  0.253333
# 728     1.0  12.0      0.0      6.0         0.0         2.0  0.253333
# 729     1.0  12.0      0.0      0.0         NaN         1.0  0.255833
# 730     NaN  12.0      0.0      1.0         1.0         2.0  0.215833
#
#         atemp       hum  windspeed  rentals
# 0    0.363625       NaN   0.160446      331
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X = data.drop(columns = ["rentals"])
y = data["rentals"]

x_train, x_test, y_train, y_test = train_test_split(
    X, y,
    test_size = 0.20, 
    random_state = 123)

# %%
from sklearn.preprocessing import StandardScaler, OrdinalEncoder
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
