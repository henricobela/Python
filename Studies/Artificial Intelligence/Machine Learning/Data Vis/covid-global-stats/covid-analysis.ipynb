# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("dark")

# %%
data_set_daily = pd.read_csv(r"data/worldometer_coronavirus_daily_data.csv")
data_set_summary = pd.read_csv(r"data/worldometer_coronavirus_summary_data.csv")

# %%
data_set_daily
# Out:
#              date      country  cumulative_total_cases  daily_new_cases  \
# 0       2020-2-15  Afghanistan                     0.0              NaN
# 1       2020-2-16  Afghanistan                     0.0              NaN
# 2       2020-2-17  Afghanistan                     0.0              NaN
# 3       2020-2-18  Afghanistan                     0.0              NaN
# 4       2020-2-19  Afghanistan                     0.0              NaN
# ...           ...          ...                     ...              ...
# 184782  2022-5-10     Zimbabwe                248642.0            106.0
# 184783  2022-5-11     Zimbabwe                248778.0            136.0
# 184784  2022-5-12     Zimbabwe                248943.0            165.0
# 184785  2022-5-13     Zimbabwe                249131.0            188.0
# 184786  2022-5-14     Zimbabwe                249206.0             75.0
#
#         active_cases  cumulative_total_deaths  daily_new_deaths
# ...

# %%
data_set_summary
# Out:
#                        country          continent  total_confirmed  \
# 0                  Afghanistan               Asia           179267
# 1                      Albania             Europe           275574
# 2                      Algeria             Africa           265816
# 3                      Andorra             Europe            42156
# 4                       Angola             Africa            99194
# ..                         ...                ...              ...
# 221  Wallis And Futuna Islands  Australia/Oceania              454
# 222             Western Sahara             Africa               10
# 223                      Yemen               Asia            11819
# 224                     Zambia             Africa           320591
# 225                   Zimbabwe             Africa           249206
#
#      total_deaths  total_recovered  active_cases  serious_or_critical  \
# 0          7690.0         162202.0        9375.0               1124.0
# ...

# %%
df = data_set_daily
df
# Out:
#              date      country  cumulative_total_cases  daily_new_cases  \
# 0       2020-2-15  Afghanistan                     0.0              NaN
# 1       2020-2-16  Afghanistan                     0.0              NaN
# 2       2020-2-17  Afghanistan                     0.0              NaN
# 3       2020-2-18  Afghanistan                     0.0              NaN
# 4       2020-2-19  Afghanistan                     0.0              NaN
# ...           ...          ...                     ...              ...
# 184782  2022-5-10     Zimbabwe                248642.0            106.0
# 184783  2022-5-11     Zimbabwe                248778.0            136.0
# 184784  2022-5-12     Zimbabwe                248943.0            165.0
# 184785  2022-5-13     Zimbabwe                249131.0            188.0
# 184786  2022-5-14     Zimbabwe                249206.0             75.0
#
#         active_cases  cumulative_total_deaths  daily_new_deaths
# ...

# %%
df["continent"] = df.apply(
    lambda row: data_set_summary[data_set_summary.country == row.country]
    .iloc[0]
    .continent,
    axis=1,
)

# %%
df
# Out:
#              date      country  cumulative_total_cases  daily_new_cases  \
# 0       2020-2-15  Afghanistan                     0.0              NaN
# 1       2020-2-16  Afghanistan                     0.0              NaN
# 2       2020-2-17  Afghanistan                     0.0              NaN
# 3       2020-2-18  Afghanistan                     0.0              NaN
# 4       2020-2-19  Afghanistan                     0.0              NaN
# ...           ...          ...                     ...              ...
# 184782  2022-5-10     Zimbabwe                248642.0            106.0
# 184783  2022-5-11     Zimbabwe                248778.0            136.0
# 184784  2022-5-12     Zimbabwe                248943.0            165.0
# 184785  2022-5-13     Zimbabwe                249131.0            188.0
# 184786  2022-5-14     Zimbabwe                249206.0             75.0
#
#         active_cases  cumulative_total_deaths  daily_new_deaths continent
# ...

# %%
df.columns
# Out:
# Index(['date', 'country', 'cumulative_total_cases', 'daily_new_cases',
#        'active_cases', 'cumulative_total_deaths', 'daily_new_deaths',
#        'continent'],
#       dtype='object')

# %%
df = df.dropna(how="any")
df
# Out:
#              date      country  cumulative_total_cases  daily_new_cases  \
# 10      2020-2-25  Afghanistan                     1.0              0.0
# 11      2020-2-26  Afghanistan                     1.0              0.0
# 12      2020-2-27  Afghanistan                     1.0              0.0
# 13      2020-2-28  Afghanistan                     1.0              0.0
# 14      2020-2-29  Afghanistan                     1.0              0.0
# ...           ...          ...                     ...              ...
# 184782  2022-5-10     Zimbabwe                248642.0            106.0
# 184783  2022-5-11     Zimbabwe                248778.0            136.0
# 184784  2022-5-12     Zimbabwe                248943.0            165.0
# 184785  2022-5-13     Zimbabwe                249131.0            188.0
# 184786  2022-5-14     Zimbabwe                249206.0             75.0
#
#         active_cases  cumulative_total_deaths  daily_new_deaths continent
# ...

# %%
for coluna in df.columns:
    count = df[coluna].value_counts()
    print(f"Coluna: {coluna}\n\nContagens:\n{count}\n\n\n\n")
# Out:
# Coluna: date
#
# Contagens:
# 2022-5-13    194
# 2022-4-21    194
# 2022-4-19    194
# 2022-4-18    194
# 2022-4-17    194
#             ...
# 2020-1-31      1
# 2020-1-30      1
# 2020-1-29      1
# 2020-1-28      1
# 2020-2-03      1
# Name: date, Length: 843, dtype: int64
#
#
#
#
# Coluna: country
#
# Contagens:
# China              843
# France             819
# Italy              819
# Sweden             819
# Philippines        819
#                   ...
# Solomon Islands    109
# Kiribati            95
# Palau               92
# Tonga               64
# Samoa               44
# Name: country, Length: 194, dtype: int64
#
#
#
#
# Coluna: cumulative_total_cases
#
# Contagens:
# 4.0          239
# 1.0          233
# 13.0         226
# 445.0        216
# 20.0         187
#             ...
# 2146798.0      1
# 2163240.0      1
# 2174093.0      1
# 2194999.0      1
# 249206.0       1
# Name: cumulative_total_cases, Length: 85282, dtype: int64
#
#
#
#
# Coluna: daily_new_cases
#
# ...

# %%
df.isnull().sum()
# Out:
# date                       0
# country                    0
# cumulative_total_cases     0
# daily_new_cases            0
# active_cases               0
# cumulative_total_deaths    0
# daily_new_deaths           0
# continent                  0
# dtype: int64

# %%
group = df.daily_new_cases.groupby(df["continent"]).sum()
group2 = df.groupby(df["continent"]).sum()
print(group)
# Out:
# continent
# Africa                10846501.0
# Asia                 130675897.0
# Australia/Oceania      7806914.0
# Europe               178257866.0
# North America         99605753.0
# South America         52684990.0
# Name: daily_new_cases, dtype: float64

# %%
x = data_set_summary["total_deaths"].groupby(data_set_summary["continent"]).sum()
order = df["continent"].value_counts().index

values = np.arange(0, 2000000, 500000)
value_increment = 1

colors = ["r", "b", "g", "c", "k", "m"]

plt.figure(figsize=(7, 6))
plt.title("Contagem de Mortes por Continente")

ax = x.plot(kind="bar", color=colors)
# sns.countplot(x = x, hue = df["continent"], order = order, dodge = False)
# sns.countplot(x = df["continent"], hue = df["continent"], order = order, dodge = False)

plt.xticks(rotation=45)
plt.xlabel("Continentes")
plt.ylabel("Contagem")
plt.yticks(values * value_increment, ["%d" % val for val in values])

for patch in ax.patches:
    y_value = patch.get_height()
    x_value = patch.get_x() + patch.get_width() / 2
    space = 1
    label = format(y_value)
    ax.annotate(
        label,
        (x_value, y_value),
        xytext=(0, space),
        textcoords="offset points",
        ha="center",
        va="bottom",
    )

# plt.legend(["Africa", "Asia", "Oceania", "Europa", "North America", "South America"],loc = 2)

plt.show()
