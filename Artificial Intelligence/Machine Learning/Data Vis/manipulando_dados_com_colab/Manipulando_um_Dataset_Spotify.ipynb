# %% [markdown]
# <a href="https://colab.research.google.com/github/henricobela/manipulando_dados_com_colab/blob/main/Manipulando_um_Dataset_Spotify.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DATASET UTILIZADO
# https://www.kaggle.com/datasets/muhmores/spotify-top-100-songs-of-20152019

# %% [markdown]
# ## Documentação pandas para manipulação
# https://pandas.pydata.org/docs/getting_started/intro_tutorials/03_subset_data.html#min-tut-03-subset

# %% [markdown]
# ### **iniciando a manipulação**

# %%
#importando as bibliotecas a serem utilizadas
import pandas as pd      #importa a biblioteca Pandas e define ela como pd para abreviação

# %%
df = pd.read_csv(r"Spotify 2010 - 2019 Top 100.csv")       # guarda na variavel "df" a leitura do arquivo csv especificado utilizando o pandas = pd.read_csv(r"alguma coisa")

# %%
df                                                         # mostra na tela a variavel "df" que contem a leitura do arquivo csv especificado - tbm pode ser utilizado print(df)
# Out:
#                                               title            artist  \
# 0                     STARSTRUKK (feat. Katy Perry)             3OH!3
# 1                       My First Kiss (feat. Ke$ha)             3OH!3
# 2                                   I Need A Dollar        Aloe Blacc
# 3     Airplanes (feat. Hayley Williams of Paramore)             B.o.B
# 4                 Nothin' on You (feat. Bruno Mars)             B.o.B
# ...                                             ...               ...
# 998                     Strike a Pose (feat. Aitch)  Young T & Bugsey
# 999       The London (feat. J. Cole & Travis Scott)        Young Thug
# 1000                                            NaN               NaN
# 1001                                            NaN               NaN
# 1002                                            NaN               NaN
#
#         top genre  year released       added    bpm  nrgy  dnce   dB  live  \
# ...

# %%
df.head(5)                                                 # mostra na tela os 5 primeiros registros da tabela
# Out:
#                                            title      artist    top genre  \
# 0                  STARSTRUKK (feat. Katy Perry)       3OH!3    dance pop
# 1                    My First Kiss (feat. Ke$ha)       3OH!3    dance pop
# 2                                I Need A Dollar  Aloe Blacc     pop soul
# 3  Airplanes (feat. Hayley Williams of Paramore)       B.o.B  atl hip hop
# 4              Nothin' on You (feat. Bruno Mars)       B.o.B  atl hip hop
#
#    year released       added    bpm  nrgy  dnce   dB  live   val    dur  \
# 0         2009.0  2022‑02‑17  140.0  81.0  61.0 -6.0  23.0  23.0  203.0
# 1         2010.0  2022‑02‑17  138.0  89.0  68.0 -4.0  36.0  83.0  192.0
# 2         2010.0  2022‑02‑17   95.0  48.0  84.0 -7.0   9.0  96.0  243.0
# 3         2010.0  2022‑02‑17   93.0  87.0  66.0 -4.0   4.0  38.0  180.0
# 4         2010.0  2022‑02‑17  104.0  85.0  69.0 -6.0   9.0  74.0  268.0
#
#    acous  spch   pop  top year artist type
# 0    0.0   6.0  70.0    2010.0         Duo
# ...

# %%
artist = df['artist']                                      # seleciona a coluna 'artist' da tabela, e guarda em uma variavel artist

# %%
artist.head(5)                                             # mostra os 5 primeiros registros da coluna 'artist' que foi guardada na variavel artist
# Out:
# 0         3OH!3
# 1         3OH!3
# 2    Aloe Blacc
# 3         B.o.B
# 4         B.o.B
# Name: artist, dtype: object

# %%
artist.shape                                               # mostra o "corpo" da coluna, no caso quantidade de linhas da coluna
# Out:
# (1003,)

# %%
release = df['year released']                              # seleciona a coluna 'year released' da tabela, e guarda em uma variavel release

# %%
newRelease = df[df['year released'] > 2011]                # guarda na variavel todos os anos acima de 2011

# %%
newRelease.head(5)                                         # mostra na tela a variavel com os 5 primerios registros
# Out:
#                                  title              artist         top genre  \
# 39                    California Gurls          Katy Perry         dance pop
# 68              This Ain't a Love Song  Scouting For Girls         dance pop
# 69                        Eenie Meenie       Sean Kingston         dance pop
# 98        We No Speak Americano (Edit)     Yolanda Be Cool  australian dance
# 116  Bounce (feat. Kelis) - Radio Edit       Calvin Harris         dance pop
#
#      year released       added    bpm  nrgy  dnce   dB  live   val    dur  \
# 39          2012.0  2022‑02‑17  125.0  75.0  79.0 -4.0  16.0  43.0  235.0
# 68          2017.0  2022‑02‑17  177.0  91.0  46.0 -4.0  38.0  55.0  211.0
# 69          2020.0  2022‑02‑17  121.0  64.0  73.0 -3.0  10.0  84.0  202.0
# 98          2020.0  2022‑02‑17  125.0  81.0  90.0 -5.0   9.0  75.0  157.0
# 116         2012.0  2020‑06‑16  128.0  96.0  78.0 -2.0  66.0  76.0  222.0
#
#      acous  spch   pop  top year artist type
# ...

# %%
newRelease.shape                                           # mostra o "corpo" da coluna, no caso quantidade de linhas da coluna
# Out:
# (788, 17)

# %%
print("Continua...")
# Out:
# Continua...
